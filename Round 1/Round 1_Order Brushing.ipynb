# %% [markdown]
# # Order Brushing - Data Analysis
# Shopee code league round 1

# %% [markdown]
# ### Given Assumption and Definition
# - Brushing shop = concentrate rate greater of equal to 3 at any instances
# - Concentrate rate = Number of orders within 1 hour/ Number of unique Buyers within 1 hours
# - Brushing buyer = buyer that contributed the ```highest proportion of orders to a shop```
# - Highest proportion of orders should include the ordres that occured in instances when brushing

# %% [markdown]
# ### Basic Concepts
# - Each ```orderid``` represnets a distinct transation on Shopee.
# - Each unique ```shopid``` is a distinct seller on Shopee.
# - Each unique ```userid``` ia a distinct buyer on Shopee.
# - Event time refers to the exact time that an order was replaced on Shopee.

# %%
import pandas as pd

# %%
df = pd.read_csv('order_brush_order.csv')

# %%
df.columns
# Out:
# Index(['orderid', 'shopid', 'userid', 'event_time'], dtype='object')

# %%
df.head(5)
# Out:
#           orderid     shopid     userid           event_time
# 0  31076582227611   93950878   30530270  2019-12-27 00:23:03
# 1  31118059853484  156423439   46057927  2019-12-27 11:54:20
# 2  31123355095755  173699291   67341739  2019-12-27 13:22:35
# 3  31122059872723   63674025  149380322  2019-12-27 13:01:00
# 4  31117075665123  127249066  149493217  2019-12-27 11:37:55

# %%
df['event_time'] = pd.to_datetime(df['event_time'])

# %%
df.shape
# Out:
# (222750, 4)

# %%
df.isna().sum()
# Out:
# orderid       0
# shopid        0
# userid        0
# event_time    0
# dtype: int64

# %%
def get_sorted_unique_by_column_name(column_name):
    t = df[column_name].unique()
    t.sort()
    return t

unique_shop_ids = get_sorted_unique_by_column_name('shopid')

# %%
groupby_shop_id_df = df.groupby('shopid')

# %%
def get_1hour_window(t):
    return t + pd.Timedelta(hours = 1)

# %%
def concentration_rate(lower_time, upper_time, same_shop_id_df):
    windowed_df = same_shop_id_df[(lower_time <= same_shop_id_df['event_time']) & 
                                  (same_shop_id_df['event_time'] <= upper_time)]
    
    number_of_order = len(windowed_df)
    unique_user_id = windowed_df['userid'].unique()
    
    return float(number_of_order)/float(unique_user_id) >= 3.0

# %%
def get_time_range_to_brushing_user_ids_to_max_number_of_orders_pair(same_shop_id_df, time_range):
    #TBD
    
    return (time_range, [], 0)

# %%
def flatten(list_of_list):
    return [val for sublist in list_of_list for val in sublist]

# %%
def get_brushing_use_id(shop_id):
    same_shope_id = groupby_shop_id_df.get_group(shop_id)
    
    time_ranges = list(map(lambda event_time : 
                           (event_time, get_1hour_window(event_time)), 
                           same_shop_id _df['event_time']))
    
    
    time_ranges_to_brushing_use_ids_to_max_number = [
        get_time_range_to_brushing_user_ids_to_max_number_of_orders_pair(same_shop_id_df, time_range) for time_range in time_ranges()  
    ]
    
    ultimate_max_number_of_orders = max(list(map(
        (lambda _, _, max_number_of_orders: max_number_of_orders), 
        time_ranges_to_brushing_use_ids_to_max_number)))
    
    ps = filter((lambda _, _, max_number_of_orders: 
                 max_number_of_orders  == ultimate_max_number_of_orders),
                time_ranges_to_brushing_use_ids_to_max_number)
    
    brushing_user_ids = np.array([brushing_uise_ids for _, brushing_user_ids, _ in ps]).flatten().unique()
    brushing_user_ids.sort()
    
    return 0

# %%
result = list(map(
    lambda shop_id: (shop_id,get_brushing_use_id(shop_id)), unique_shop_ids)
             )

# %%
result_df = pd.DataFrame(result, columns = ['shopid', 'userid'])

# %%
result_df
# Out:
#           shopid  userid
# 0          10009       0
# 1          10051       0
# 2          10061       0
# 3          10084       0
# 4          10100       0
# ...          ...     ...
# 18765  214662358       0
# 18766  214949521       0
# 18767  214964814       0
# 18768  215175775       0
# 18769  215435223       0
#
# [18770 rows x 2 columns]

# %% [markdown]
# ## Trial

# %%
temp_df = df[df['shopid'] == 147941492].sort_values(by = 'event_time')
temp_df = temp_df.set_index('event_time')

# %%
count_df = temp_df.groupby([temp_df.index.date, temp_df.index.hour])['orderid'].count().reset_index()

# %%
count_df
# Out:
#         level_0  event_time  orderid
# 0    2019-12-27           0      268
# 1    2019-12-27           1      104
# 2    2019-12-27           2       52
# 3    2019-12-27           3       34
# 4    2019-12-27           4        9
# ..          ...         ...      ...
# 115  2019-12-31          19       89
# 116  2019-12-31          20       73
# 117  2019-12-31          21       59
# 118  2019-12-31          22       72
# 119  2019-12-31          23       94
#
# [120 rows x 3 columns]

# %%
(count_df['orderid'] >= 3).any()
# Out:
# True

# %%
print(temp_df['shopid'].unique())
# Out:
# [147941492]

# %% [markdown]
# ### Acquire shopid

# %%
shopid_list = []
for i in df['shopid'].unique():
    temp_df = df[df['shopid'] == i].sort_values(by = 'event_time').set_index('event_time')
    count_df = temp_df.groupby([temp_df.index.date, temp_df.index.hour])['orderid'].count().reset_index()
    if (count_df['orderid'] >= 3).any():
        print(i)
        shopid_list.append(i)
# Out:
# 93950878
# 173699291
# 127249066
# 107921853
# 178400128
# 147941492
# 9374147
# 145694343
# 30988921
# 67162407
# 65883234
# 33242381
# 3285661
# 95138572
# 12662873
# 152569117
# 8051258
# 12480907
# 51526935
# 43719124
# 161269907
# 1175477
# 39938958
# 93363430
# 96757689
# 90339629
# 137754804
# 152871252
# 67960532
# 64625969
# 4669871
# 62713846
# 39554718
# 47415942
# 173718481
# 112904482
# 24759976
# 54615708
# 64492135
# 175116620
# 641249
# 172185419
# 66861410
# 140937896
# 8715449
# 129257169
# 99787848
# 158448460
# 115294353
# 84547411
# 8121841
# 61556313
# 137762642
# 147398485
# 66342314
# 25924280
# 65885656
# 53613428
# 760726
# 131198971
# 171947507
# 182347785
# 117919981
# 129926253
# 51487475
# 5354812
# 17911218
# 107932444
# 76199702
# 32504026
# 27998060
# 141605375
# 122218940
# 201015462
# 130128043
# 85948343
# 22502375
# 84301799
# 41282916
# 83102588
# 151865497
# 23958390
# 58543771
# 156883302
# 1532569
# 17749654
# 12568
# 129736159
# 27476241
# 96869191
# 10208
# 26056025
# 40429317
# 58835561
# 6285560
# 26218382
# 28091290
# 10891360
# 116499414
# 101590068
# 96953349
# 121742138
# 160305762
# 140589385
# 80049863
# 135054910
# 64909454
# 120981896
# 210197928
# 28622157
# 183068
# 9029100
# 48658870
# 59599139
# 18784836
# 118949474
# 64909117
# 113952977
# 104590058
# 24013881
# 10127469
# 49174497
# 165259123
# 45331410
# 151349322
# 16107
# 38015541
# 57885771
# 129017444
# 131669646
# 42181947
temp_df = temp_df.set_index('event_time')

# %%
temp_df['Count order in last hour'] = temp_df['orderid'].rolling('3600s').count()

# %%
temp_df.reset_index()
# Out:
#                event_time         orderid     shopid     userid  \
# 0     2019-12-27 00:00:08  31075208826809  147941492  195903090
# 1     2019-12-27 00:00:12  31075212032449  147941492  210365192
# 2     2019-12-27 00:00:31  31075231334015  147941492     306545
# 3     2019-12-27 00:00:32  31075232254299  147941492  202519981
# 4     2019-12-27 00:00:33  31075232409868  147941492  200500884
# ...                   ...             ...        ...        ...
# 11698 2019-12-31 23:58:17  31507096850803  147941492  120006484
# 11699 2019-12-31 23:58:28  31507108119827  147941492   12390455
# 11700 2019-12-31 23:58:59  31507139137451  147941492  197985002
# 11701 2019-12-31 23:59:42  31507181180213  147941492  167249884
# 11702 2019-12-31 23:59:47  31507187390691  147941492   40258063
#
#        Count order in last hour
# 0                           1.0
# 1                           2.0
# 2                           3.0
# 3                           4.0
# 4                           5.0
# ...                         ...
# 11698                      91.0
# 11699                      91.0
# 11700                      92.0
# 11701                      93.0
# 11702                      94.0
#
# [11703 rows x 5 columns]

# %%
temp_df['Count unique_user in last hour'] = temp_df.transform(lambda x:\
                                                              len(temp_df[(temp_df['event_time'].between(x['event_time'] - datetime.timedelta(hours=1),
                                                                                                      x['event_time']))]['userid'].unique()), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'event_time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-178-1ed8ae837986> in <module>
#       1 temp_df['Count unique_user in last hour'] = temp_df.transform(lambda x:\
#       2                                                               len(temp_df[(temp_df['event_time'].between(x['event_time'] - datetime.timedelta(hours=1),
# ----> 3                                                                                                       x['event_time']))]['userid'].unique()), axis=1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in transform(self, func, axis, *args, **kwargs)
#    6717         axis = self._get_axis_number(axis)
#    6718         if axis == 1:
# -> 6719             return self.T.transform(func, *args, **kwargs).T
#    6720         return super().transform(func, *args, **kwargs)
#    6721
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in transform(self, func, axis, *args, **kwargs)
#    6718         if axis == 1:
#    6719             return self.T.transform(func, *args, **kwargs).T
# -> 6720         return super().transform(func, *args, **kwargs)
#    6721
#    6722     def apply(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in transform(self, func, *args, **kwargs)
#   10810     @Appender(_shared_docs["transform"] % dict(axis="", **_shared_doc_kwargs))
#   10811     def transform(self, func, *args, **kwargs):
# > 10812         result = self.agg(func, *args, **kwargs)
#   10813         if is_scalar(result) or len(result) != len(self):
#   10814             raise ValueError("transforms cannot produce " "aggregated results")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in aggregate(self, func, axis, *args, **kwargs)
#    6699             pass
#    6700         if result is None:
# -> 6701             return self.apply(func, axis=axis, args=args, **kwargs)
#    6702         return result
#    6703
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-178-1ed8ae837986> in <lambda>(x)
#       1 temp_df['Count unique_user in last hour'] = temp_df.transform(lambda x:\
# ----> 2                                                               len(temp_df[(temp_df['event_time'].between(x['event_time'] - datetime.timedelta(hours=1),
#       3                                                                                                       x['event_time']))]['userid'].unique()), axis=1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('event_time', 'occurred at index 2019-12-27 00:00:08')

# %%
temp_df['userid'].unique()
# Out:
# array([195903090, 210365192,    306545, ..., 120006484,  12390455,
#        197985002])
